# %%
# PANDAS - Manipulação de dados
#importa a biblioteca pandas
# - Dataframes - funciona como uma planilha do excel, onde cada coluna tem um tipo de dado diferente
#import pandas as pd


#NUMPY  - para numeros (matematica, arrays)
#importa a biblioteca NUMPY
#import numpy as np


#MATPLOT - Para criacao de graficos
#importa a biblioteca MATPLOT
#import matplotlib.pyplot as plt



import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#NUMPY
array = np.array([1, 2, 3, 4, 5])
print(array)
print("*" * 30)

# PANDAS
dados = {'Nome': ['Alice', 'Bob', 'Charlie'], 'Idade': [25, 30, 35]}
df = pd.DataFrame(dados)
print(df)
print("*" * 30)
df.info() # para mostrar as informações do dataframe
print("*" * 30)

# recebendo um dataframe
# pd.read.csv('dados.csv') - para ler um arquivo csv e transformar em um dataframe
'''df = pd.read_csv('dados.csv')
print(df)
print("*" * 30)'''


# MATPLOTLIB
x = np.array([1, 2, 3, 4, 5])
y = np.array([2, 3, 5, 7, 11])
plt.plot(x, y) # cria um grafico de linha
plt.show() # SHOW() exibe o grafico
# Out:
# [1 2 3 4 5]
# ******************************
#       Nome  Idade
# 0    Alice     25
# 1      Bob     30
# 2  Charlie     35
# ******************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Nome    3 non-null      object
#  1   Idade   3 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 180.0+ bytes
# ******************************

# %%
# Manipulando dados
import matplotlib.pyplot as plt
x = np.array([1, 2, 3, 4, 5])
y = np.array([2, 4, 6, 8, 10])
plt.plot(x, y) 
plt.show() 

# Operações com arrays
numeros = np.array([1, 2, 3, 4, 5])
resultado = numeros * 2
print(resultado)
# Out:
# [ 2  4  6  8 10]

# %%
# criar arquivo csv PANDAS()
dados = {'Nome': ['Alice', 'Bob', 'Charlie'], 'Idade': [25, 30, 35]}
df = pd.DataFrame(dados)
df.to_csv('dados.csv', index=False) # index=False para não criar uma coluna de index

df = pd.read_csv('dados.csv')
print(df)
# Out:
#       Nome  Idade
# 0    Alice     25
# 1      Bob     30
# 2  Charlie     35
